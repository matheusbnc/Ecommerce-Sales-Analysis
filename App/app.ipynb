# %%
from menus.menus import *
from results.produtos import *
from results.clientes import *
from results.paises import *
from preprocessing.formatting import title_col, change_types, pre_processing, drop_nan\
                                        , drop_uk, add_time_columns
from time import sleep
import pandas as pd

# Função principal para executar o programa
def main():
    
    retail = pd.read_csv('Data/Online Retail.csv', delimiter=';', encoding='latin1', decimal=',')
    retail = pre_processing(retail)
    change_types(retail)

    while True:
        main_menu()
        sleep(0.5)
        opcao = input('\nEscolha uma opção: ')
        sleep(0.5)
        
        if opcao == '1':
            while True:
                
                sleep(0.5)
                produto_submenu()
                opcao_produto = input('\nEscolha uma opção: ')
                
                if opcao_produto == '1':
                    more_units_sold(retail)
                    
                elif opcao_produto == '2':
                    more_profitable(retail)
                    
                elif opcao_produto == '3':
                    frequent_sales(retail)
                    
                elif opcao_produto == '4':
                    more_units_canceled(retail)
                    
                elif opcao_produto == '5':
                    expensive_cancellations(retail)
                
                elif opcao_produto == '6':
                    frequent_cancellations(retail)

                elif opcao_produto == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')

        elif opcao == '2':

            retail_cli = drop_nan(retail)
            
            while True:
                
                sleep(0.5)
                cliente_submenu()
                opcao_cliente = input('\nEscolha uma opção: ')
                
                if opcao_cliente == '1':
                    more_units_sold_clients(retail_cli)
                    
                elif opcao_cliente == '2':
                    more_profitable_clients(retail_cli)
                    
                elif opcao_cliente == '3':
                    frequent_clients(retail_cli)
                
                elif opcao_cliente == '4':
                    more_units_canceled_clients(retail_cli)
                    
                elif opcao_cliente == '5':
                    expensive_cancellations_clients(retail_cli)
                    
                elif opcao_cliente == '6':
                    frequent_cancellations_clients(retail_cli)
                    
                elif opcao_cliente == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')
                    
        elif opcao == '3':
            
            retail_ctr = drop_uk(retail)
            
            while True:
                
                sleep(0.5)
                pais_submenu()
                opcao_pais = input('\nEscolha uma opção: ')
                
                if opcao_pais == '1':
                    more_units_sold_country(retail_ctr)
                    
                elif opcao_pais == '2':
                    more_profitable_country(retail_ctr)
                    
                elif opcao_pais == '3':
                    frequent_sales_country(retail_ctr)
                    
                elif opcao_pais == '4':
                    more_units_canceled_country(retail_ctr)
                    
                elif opcao_pais == '5':
                    expensive_cancellations_country(retail_ctr)
                    
                elif opcao_pais == '6':
                    frequent_cancellations_country(retail_ctr)
                    
                elif opcao_pais == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')
                    
        elif opcao == '4':
            
            retail_saz =  add_time_columns(retail)
            
            while True:
                
                sleep(0.5)
                sazonalidade_submenu()
                opcao_sazonalidade = input('\nEscolha uma opção: ')
                
                if opcao_sazonalidade == '1':
                    print(retail_saz.head())
                    
                elif opcao_sazonalidade == '2':
                    pass
                elif opcao_sazonalidade == '3':
                    pass
                elif opcao_sazonalidade == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')
                    
        elif opcao == '0':
            print('\nSaindo do programa...')
            break

        else:
            print('\nOpção inválida. Por favor, escolha uma opção válida.\n')

if __name__ == '__main__':
    main()
# Out:
# ================================================================================
#                                  MENU PRINCIPAL
# ================================================================================
# 1. Análise de Produtos
# 2. Análise de Clientes
# 3. Análise de Países
# 4. Análise de Sazonalidade
# ================================================================================
# 0. Sair
#
# Escolha uma opção: 1
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 1
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#                            Description  Quantity
# 0    World War 2 Gliders Asstd Designs     53751
# 1              Jumbo Bag Red Retrospot     47256
# 2                       Popcorn Holder     36322
# 3        Assorted Colour Bird Ornament     36282
# 4      Pack Of 72 Retrospot Cake Cases     36016
# 5   White Hanging Heart T-Light Holder     35294
# 6                   Rabbit Night Light     30631
# 7              Mini Paint Set Vintage      26437
# 8           Pack Of 12 London Tissues      26095
# 9   Pack Of 60 Pink Paisley Cake Cases     24719
# 10     Victorian Glass Hanging T-Light     23825
# 11           Assorted Colours Silk Fan     23082
# 12                 Brocade Ring Purse      23017
# 13              Red  Harmonica In Box      21836
# 14             Jumbo Bag Pink Polkadot     20992
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 2
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#                            Description  FinalPrice
# 0             Regency Cakestand 3 Tier   164459.49
# 1   White Hanging Heart T-Light Holder    99612.42
# 2                        Party Bunting    98243.88
# 3              Jumbo Bag Red Retrospot    92175.79
# 4                   Rabbit Night Light    66661.63
# 5      Paper Chain Kit 50'S Christmas     63715.24
# 6        Assorted Colour Bird Ornament    58792.42
# 7                        Chilli Lights    53746.66
# 8                       Spotty Bunting    42030.67
# 9              Jumbo Bag Pink Polkadot    41584.43
# 10            Black Record Cover Frame    40578.21
# 11      Picnic Basket Wicker 60 Pieces    39619.50
# 12   Set Of 3 Cake Tins Pantry Design     37378.79
# 13       Doormat Keep Calm And Come In    36532.39
# 14            Jam Making Set With Jars    36069.34
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 3
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#                            Description  InvoiceNo
# 0   White Hanging Heart T-Light Holder       2311
# 1              Jumbo Bag Red Retrospot       2109
# 2             Regency Cakestand 3 Tier       2007
# 3                        Party Bunting       1699
# 4              Lunch Bag Red Retrospot       1581
# 5        Assorted Colour Bird Ornament       1476
# 6    Set Of 3 Cake Tins Pantry Design        1392
# 7      Pack Of 72 Retrospot Cake Cases       1352
# 8              Lunch Bag  Black Skull.       1301
# 9      Natural Slate Heart Chalkboard        1255
# 10             Jumbo Bag Pink Polkadot       1232
# 11               Heart Of Wicker Small       1219
# 12              Jumbo Storage Bag Suki       1194
# 13     Paper Chain Kit 50'S Christmas        1184
# 14   Jumbo Shopper Vintage Red Paisley       1180
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 4
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#                             Description  Quantity
# 0           Paper Craft , Little Birdie     80995
# 1        Medium Ceramic Top Storage Jar     74494
# 2   Rotating Silver Angels T-Light Hldr      9376
# 3    Fairy Cake Flannel Assorted Colour      3150
# 4    White Hanging Heart T-Light Holder      2578
# 5           Gin + Tonic Diet Metal Sign      2030
# 6                     Herb Marker Basil      1527
# 7                  Feltcraft Doll Molly      1447
# 8                Tea Time Party Bunting      1424
# 9           Paper Pocket Traveling Fan       1385
# 10     Pink Blue Felt Craft Trinket Box      1321
# 11    World War 2 Gliders Asstd Designs      1200
# 12    Colour Glass. Star T-Light Holder      1174
# 13              Jumbo Bag Red Retrospot      1115
# 14                  Home Sweet Home Mug      1052
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 5
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#                            Description  FinalPrice
# 0          Paper Craft , Little Birdie   168469.60
# 1       Medium Ceramic Top Storage Jar    77479.64
# 2             Regency Cakestand 3 Tier     9697.05
# 3   White Hanging Heart T-Light Holder     6624.30
# 4   Fairy Cake Flannel Assorted Colour     6591.42
# 5                Pantry Chopping Board     4803.06
# 6                   Doormat Fairy Cake     4554.90
# 7          Gin + Tonic Diet Metal Sign     3775.33
# 8               Tea Time Party Bunting     3692.95
# 9                 Feltcraft Doll Molly     3512.65
# 10   Colour Glass. Star T-Light Holder     3246.16
# 11              Ivory Diner Wall Clock     2653.70
# 12            Red Retrospot Cake Stand     2480.50
# 13             Jumbo Bag Red Retrospot     1984.02
# 14   Flowers Chandelier T-Light Holder     1859.07
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 6
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#                            Description  InvoiceNo
# 0             Regency Cakestand 3 Tier        180
# 1             Jam Making Set With Jars         87
# 2    Set Of 3 Cake Tins Pantry Design          73
# 3     Roses Regency Teacup And Saucer          54
# 4       Strawberry Ceramic Trinket Box         54
# 5      Recipe Box Pantry Yellow Design         47
# 6              Jumbo Bag Red Retrospot         44
# 7              Lunch Bag Red Retrospot         44
# 8      Green Regency Teacup And Saucer         42
# 9   Wood 2 Drawer Cabinet White Finish         42
# 10  White Hanging Heart T-Light Holder         42
# 11            Red Retrospot Cake Stand         42
# 12       Small Glass Heart Trinket Pot         40
# 13          Set Of 3 Regency Cake Tins         37
# 14                      Popcorn Holder         36
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE PRODUTOS
# ================================================================================
# 1. Produtos Mais Vendidos [Unidades]
# 2. Produtos Mais Vendidos [Valor (£)]
# 3. Produtos Mais Vendidos [Ocorrências]
# 4. Produtos Mais Cancelados [Unidades]
# 5. Produtos Mais Cancelados [Valor (£)]
# 6. Produtos Mais Cancelados [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 0
# ================================================================================
#                                  MENU PRINCIPAL
# ================================================================================
# 1. Análise de Produtos
# 2. Análise de Clientes
# 3. Análise de Países
# 4. Análise de Sazonalidade
# ================================================================================
# 0. Sair
#
# Escolha uma opção: 2
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 1
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#    CustomerID  Quantity
# 0       14646    196556
# 1       12415     76946
# 2       14911     76823
# 3       17450     69021
# 4       18102     64124
# 5       17511     63014
# 6       13694     61904
# 7       14298     58021
# 8       14156     56896
# 9       16684     49391
# 10      15311     37673
# 11      16029     33687
# 12      16422     33584
# 13      17404     32320
# 14      16333     32184
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 2
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#    CustomerID  FinalPrice
# 0       14646   278778.02
# 1       18102   259657.30
# 2       17450   189575.53
# 3       14911   128768.24
# 4       12415   123638.18
# 5       14156   113685.77
# 6       17511    88138.20
# 7       16684    65920.12
# 8       13694    62961.54
# 9       16029    60369.93
# 10      15311    59284.19
# 11      13089    57322.13
# 12      15061    54250.34
# 13      14096    53258.43
# 14      17949    53215.74
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 3
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#    CustomerID  InvoiceNo
# 0       17841       7667
# 1       14911       5584
# 2       14096       5095
# 3       12748       4397
# 4       14606       2674
# 5       15311       2366
# 6       14646       2060
# 7       13089       1814
# 8       13263       1662
# 9       14298       1637
# 10      15039       1477
# 11      14156       1382
# 12      18118       1262
# 13      14159       1174
# 14      14796       1131
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 4
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#    CustomerID  Quantity
# 0       16446     80995
# 1       12346     74215
# 2       15838      9360
# 3       15749      9014
# 4       16029      6420
# 5       12931      4427
# 6       14607      3768
# 7       14911      3331
# 8       17949      2878
# 9       15482      2022
# 10      15769      2012
# 11      12901      1776
# 12      16013      1594
# 13      12748      1535
# 14      17511      1535
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 5
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#    CustomerID  FinalPrice
# 0       16446   168469.60
# 1       12346    77183.60
# 2       15749    22998.40
# 3       16029    12338.16
# 4       12931     8511.15
# 5       14911     7393.59
# 6       14607     5228.40
# 7       17450     4815.26
# 8       17949     4814.74
# 9       15482     4486.24
# 10      15769     4429.00
# 11      16013     3677.15
# 12      12454     3528.34
# 13      17511     2924.18
# 14      14156     2874.31
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 6
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#    CustomerID  InvoiceNo
# 0       14911        222
# 1       17841        133
# 2       15311        112
# 3       17511        111
# 4       12607        101
# 5       14410         91
# 6       13798         89
# 7       14606         81
# 8       13113         78
# 9       12471         70
# 10      14680         62
# 11      12415         61
# 12      12472         52
# 13      12709         48
# 14      13534         46
# ========================================================================================================================
#
# ================================================================================
#                               ANÁLISE DE CLIENTES
# ================================================================================
# 1. Clientes Mais Compradores [Unidades]
# 2. Clientes Mais Compradores [Valor (£)]
# 3. Clientes Mais Compradores [Ocorrências]
# 4. Clientes com Mais Cancelamento [Unidades]
# 5. Clientes com Mais Cancelamento [Valor (£)]
# 6. Clientes com Mais Cancelamento [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 0
# ================================================================================
#                                  MENU PRINCIPAL
# ================================================================================
# 1. Análise de Produtos
# 2. Análise de Clientes
# 3. Análise de Países
# 4. Análise de Sazonalidade
# ================================================================================
# 0. Sair
#
# Escolha uma opção: 3
#
# ================================================================================
#                                ANÁLISE DE PAÍSES
# ================================================================================
# 1. Países Estrangeiros Mais Compradores [Unidades]
# 2. Países Estrangeiros Mais Compradores [Valor (£)]
# 3. Países Estrangeiros Mais Compradores [Ocorrências]
# 4. Países Estrangeiros com Mais Cancelamentos [Unidades]
# 5. Países Estrangeiros com Mais Cancelamentos [Valor (£)]
# 6. Países Estrangeiros com Mais Cancelamentos [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 1
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#             Country  Quantity
# 0       Netherlands    199934
# 1              EIRE    142120
# 2           Germany    116234
# 3            France    109648
# 4         Australia     83335
# 5            Sweden     35594
# 6       Switzerland     30215
# 7             Spain     26600
# 8             Japan     25221
# 9           Belgium     22880
# 10           Norway     19188
# 11         Portugal     16055
# 12          Finland     10575
# 13  Channel Islands      9470
# 14          Denmark      8147
# ========================================================================================================================
#
# ================================================================================
#                                ANÁLISE DE PAÍSES
# ================================================================================
# 1. Países Estrangeiros Mais Compradores [Unidades]
# 2. Países Estrangeiros Mais Compradores [Valor (£)]
# 3. Países Estrangeiros Mais Compradores [Ocorrências]
# 4. Países Estrangeiros com Mais Cancelamentos [Unidades]
# 5. Países Estrangeiros com Mais Cancelamentos [Valor (£)]
# 6. Países Estrangeiros com Mais Cancelamentos [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 2
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#             Country  FinalPrice
# 0       Netherlands   283479.54
# 1              EIRE   259380.02
# 2           Germany   200619.66
# 3            France   182076.60
# 4         Australia   136922.50
# 5       Switzerland    52483.05
# 6             Spain    51746.65
# 7           Belgium    36662.96
# 8             Japan    35419.79
# 9            Sweden    35166.41
# 10           Norway    32292.96
# 11         Portugal    26807.47
# 12  Channel Islands    19926.39
# 13          Finland    18303.54
# 14          Denmark    18042.14
# ========================================================================================================================
#
# ================================================================================
#                                ANÁLISE DE PAÍSES
# ================================================================================
# 1. Países Estrangeiros Mais Compradores [Unidades]
# 2. Países Estrangeiros Mais Compradores [Valor (£)]
# 3. Países Estrangeiros Mais Compradores [Ocorrências]
# 4. Países Estrangeiros com Mais Cancelamentos [Unidades]
# 5. Países Estrangeiros com Mais Cancelamentos [Valor (£)]
# 6. Países Estrangeiros com Mais Cancelamentos [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 3
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#             Country  InvoiceNo
# 0           Germany       8643
# 1            France       8085
# 2              EIRE       7768
# 3             Spain       2417
# 4       Netherlands       2322
# 5           Belgium       1935
# 6       Switzerland       1927
# 7          Portugal       1455
# 8         Australia       1180
# 9            Norway       1048
# 10  Channel Islands        743
# 11            Italy        741
# 12          Finland        647
# 13           Cyprus        601
# 14      Unspecified        442
# ========================================================================================================================
#
# ================================================================================
#                                ANÁLISE DE PAÍSES
# ================================================================================
# 1. Países Estrangeiros Mais Compradores [Unidades]
# 2. Países Estrangeiros Mais Compradores [Valor (£)]
# 3. Países Estrangeiros Mais Compradores [Ocorrências]
# 4. Países Estrangeiros com Mais Cancelamentos [Unidades]
# 5. Países Estrangeiros com Mais Cancelamentos [Valor (£)]
# 6. Países Estrangeiros com Mais Cancelamentos [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 4
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#            Country  Quantity
# 0             EIRE      4776
# 1          Germany      1798
# 2           France      1578
# 3              USA      1424
# 4            Spain      1124
# 5            Japan       795
# 6        Australia       555
# 7           Sweden       443
# 8      Netherlands       324
# 9      Switzerland       300
# 10           Italy       110
# 11          Norway        88
# 12         Belgium        82
# 13  Czech Republic        78
# 14        Portugal        71
# ========================================================================================================================
#
# ================================================================================
#                                ANÁLISE DE PAÍSES
# ================================================================================
# 1. Países Estrangeiros Mais Compradores [Unidades]
# 2. Países Estrangeiros Mais Compradores [Valor (£)]
# 3. Países Estrangeiros Mais Compradores [Ocorrências]
# 4. Países Estrangeiros com Mais Cancelamentos [Unidades]
# 5. Países Estrangeiros com Mais Cancelamentos [Valor (£)]
# 6. Países Estrangeiros com Mais Cancelamentos [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 5
#                                                     RESUMO DOS DADOS
# ========================================================================================================================
#         Country  FinalPrice
# 0          EIRE    11470.84
# 1       Germany     4761.49
# 2         Spain     3959.91
# 3        France     2416.40
# 4         Japan     1996.58
# 5           USA     1849.47
# 6        Sweden     1662.42
# 7     Australia     1181.31
# 8   Switzerland      582.55
# 9         Italy      543.90
# 10  Netherlands      409.80
# 11       Cyprus      323.40
# 12      Belgium      264.38
# 13       Israel      227.44
# 14      Bahrain      205.74
# ========================================================================================================================
#
# ================================================================================
#                                ANÁLISE DE PAÍSES
# ================================================================================
# 1. Países Estrangeiros Mais Compradores [Unidades]
# 2. Países Estrangeiros Mais Compradores [Valor (£)]
# 3. Países Estrangeiros Mais Compradores [Ocorrências]
# 4. Países Estrangeiros com Mais Cancelamentos [Unidades]
# 5. Países Estrangeiros com Mais Cancelamentos [Valor (£)]
# 6. Países Estrangeiros com Mais Cancelamentos [Ocorrências]
# ================================================================================
# 0. Voltar ao Menu Principal

# %% [markdown]
# #
