# %%
from menus.menus import *
from Resultados.produtos import *
from Resultados.clientes import *
from Resultados.paises import *
from functions.functions import title_col, change_types, pre_processing, drop_nan
from time import sleep
import pandas as pd

# Função principal para executar o programa
def main():
    
    retail = pd.read_csv('Data/Online Retail.csv', delimiter=';', encoding='latin1', decimal=',')
    retail = pre_processing(retail)
    change_types(retail)

    while True:
        main_menu()
        sleep(0.5)
        opcao = input('\nEscolha uma opção: ')
        sleep(0.5)
        
        if opcao == '1':
            while True:
                
                sleep(0.5)
                produto_submenu()
                opcao_produto = input('\nEscolha uma opção: ')
                
                if opcao_produto == '1':
                    more_units_sold(retail)
                    
                elif opcao_produto == '2':
                    more_profitable(retail)
                    
                elif opcao_produto == '3':
                    frequent_sales(retail)
                    
                elif opcao_produto == '4':
                    more_units_canceled(retail)
                    
                elif opcao_produto == '5':
                    expensive_cancellations(retail)
                
                elif opcao_produto == '6':
                    frequent_cancellations(retail)

                elif opcao_produto == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')

        elif opcao == '2':

            retail_cli = drop_nan(retail)
            
            while True:
                
                sleep(0.5)
                cliente_submenu()
                opcao_cliente = input('\nEscolha uma opção: ')
                
                if opcao_cliente == '1':
                    more_units_sold_clients(retail_cli)
                    
                elif opcao_cliente == '2':
                    more_profitable_clients(retail_cli)
                    
                elif opcao_cliente == '3':
                    frequent_clients(retail_cli)
                
                elif opcao_cliente == '4':
                    more_units_canceled_clients(retail_cli)
                    
                elif opcao_cliente == '5':
                    expensive_cancellations_clients(retail_cli)
                    
                elif opcao_cliente == '6':
                    frequent_cancellations_clients(retail_cli)
                    
                elif opcao_cliente == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')
                    
        elif opcao == '3':
            
            retail_ctr = drop_uk(retail)
            
            while True:
                
                sleep(0.5)
                pais_submenu()
                opcao_pais = input('\nEscolha uma opção: ')
                
                if opcao_pais == '1':
                    more_units_sold_country(retail_ctr)
                    
                elif opcao_pais == '2':
                    more_profitable_country(retail_ctr)
                    
                elif opcao_pais == '3':
                    pass
                elif opcao_pais == '4':
                    pass            
                elif opcao_pais == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')
                    
        elif opcao == '4':
            while True:
                
                sleep(0.5)
                sazonalidade_submenu()
                opcao_sazonalidade = input('\nEscolha uma opção: ')
                
                if opcao_sazonalidade == '1':
                    pass
                    
                elif opcao_sazonalidade == '2':
                    pass
                elif opcao_sazonalidade == '3':
                    pass
                elif opcao_sazonalidade == '0':
                    break
                    
                else:
                    print('\nOpção inválida. Por favor, escolha uma opção válida.\n')
                    
        elif opcao == '0':
            print('\nSaindo do programa...')
            break

        else:
            print('\nOpção inválida. Por favor, escolha uma opção válida.\n')

if __name__ == '__main__':
    main()
# Out:
# Menu Principal:
# 1. Análise de Produtos
# 2. Análise de Clientes
# 3. Análise de Países
# 4. Análise de Sazonalidade
# 0. Sair
#
# Escolha uma opção: 3
#
# Análise de Países:
# 1. Quais são os países com os maiores volumes de vendas no período?
# 2. Quais são os países que mais geraram receita no período?
# 3. Quais são os países com mais ocorrências de cancelamento no período?
# 4. Quais são os países com maior valor médio de compra por transação no período?
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 1
#             Country  Quantity
# 0       Netherlands    199934
# 1              EIRE    142120
# 2           Germany    116234
# 3            France    109648
# 4         Australia     83335
# 5            Sweden     35594
# 6       Switzerland     30215
# 7             Spain     26600
# 8             Japan     25221
# 9           Belgium     22880
# 10           Norway     19188
# 11         Portugal     16055
# 12          Finland     10575
# 13  Channel Islands      9470
# 14          Denmark      8147
#
# Análise de Países:
# 1. Quais são os países com os maiores volumes de vendas no período?
# 2. Quais são os países que mais geraram receita no período?
# 3. Quais são os países com mais ocorrências de cancelamento no período?
# 4. Quais são os países com maior valor médio de compra por transação no período?
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 2
#             Country  FinalPrice
# 0       Netherlands   283479.54
# 1              EIRE   259380.02
# 2           Germany   200619.66
# 3            France   182076.60
# 4         Australia   136922.50
# 5       Switzerland    52483.05
# 6             Spain    51746.65
# 7           Belgium    36662.96
# 8             Japan    35419.79
# 9            Sweden    35166.41
# 10           Norway    32292.96
# 11         Portugal    26807.47
# 12  Channel Islands    19926.39
# 13          Finland    18303.54
# 14          Denmark    18042.14
#
# Análise de Países:
# 1. Quais são os países com os maiores volumes de vendas no período?
# 2. Quais são os países que mais geraram receita no período?
# 3. Quais são os países com mais ocorrências de cancelamento no período?
# 4. Quais são os países com maior valor médio de compra por transação no período?
# 0. Voltar ao Menu Principal
#
# Escolha uma opção: 0
# Menu Principal:
# 1. Análise de Produtos
# 2. Análise de Clientes
# 3. Análise de Países
# 4. Análise de Sazonalidade
# 0. Sair
#
# Escolha uma opção: 0
#
# Saindo do programa...

# %% [markdown]
# #
